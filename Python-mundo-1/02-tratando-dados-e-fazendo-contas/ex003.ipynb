# %%
a = int(input("Digite um número: "))
b = int(input("Digite outro número: "))
soma = a + b

print("A soma de {} e {} é igual a {}".format(a, b, soma))
# Out:
# Digite um número: 5
# Digite outro número: 6
# A soma de 5 e 6 é igual a 11
