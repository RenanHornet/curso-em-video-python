# %%
num = int(input("Digite um número: "))


print("O número digitado foi {}, seu antecessor é {} e seu sucessor é {}".format(num, (num-1), (num + 1)))
# Out:
# Digite um número: 5
# O número digitado foi 5, seu antecessor é 4 e seu sucessor é 6
