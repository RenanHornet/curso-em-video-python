# %%
#Crie um programa que leia o ano de nascimento de sete pessoas.
#No final, mostre quantas pessoas ainda não atingiram a maioridade e quantas já são maiores.

print('='*30)
print('Grupo da maioridade')
print('='*30)
print('\n\n\n')
from datetime import date
atual = date.today().year
maior = 0
menor = 0
for c in range (1, 8):
  idade = int(input(f'Em que ano a {c}ª pessoa nasceu? '))
  if atual - idade >= 18:
    maior += 1
  else:
    menor += 1
print(f'Temos um total de {maior} pessoas maiores de idade.')
print(f'Temos um total de {menor} pessoas menores de idade.')
# Out:
# ==============================
# Grupo da maioridade
# ==============================
#
#
#
#
# Em que ano a 1ª pessoa nasceu? 1989
# Em que ano a 2ª pessoa nasceu? 1999
# Em que ano a 3ª pessoa nasceu? 2009
# Em que ano a 4ª pessoa nasceu? 2019
# Em que ano a 5ª pessoa nasceu? 2015
# Em que ano a 6ª pessoa nasceu? 2000
# Em que ano a 7ª pessoa nasceu? 1988
# Temos um total de 4 pessoas maiores de idade.
# Temos um total de 3 pessoas menores de idade.
